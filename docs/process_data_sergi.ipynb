# %%
import os
import pandas as pd
import numpy as np

# %%
os.getcwd()
# Out:
# '/Users/sergigomezpalleja/code_sergi/hackcancer/intelcancer/docs'

# %%
data = pd.read_csv('CosmicMutantExportCensus.tsv',delimiter='\t')
# Out:
# /Users/sergigomezpalleja/anaconda3/envs/kaggle/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head()
# Out:
#   Gene name Accession Number  Gene CDS length HGNC ID Sample name  ID_sample  \
# 0      JAK2  ENST00000381652             3399    6192      990000     990000
# 1      BRAF  ENST00000288602             2301    1097      E22133     683800
# 2      BRAF  ENST00000288602             2301    1097      E21904     686500
# 3      TP53  ENST00000269305             1182   11998   NCI-H1184     688000
# 4      KRAS  ENST00000311936              567    6407      S30505     709800
#
#    ID_tumour                        Primary site Site subtype 1  \
# 0     905319  haematopoietic_and_lymphoid_tissue             NS
# 1     611960                       biliary_tract      bile_duct
# 2     614660                             thyroid             NS
# 3     616160                                lung             NS
# 4     635643                            pancreas             NS
#
#   Site subtype 2 ...  Resistance Mutation FATHMM prediction FATHMM score  \
# ...

# %%
data.shape
# Out:
# (711454, 36)

# %%
data['drug_resist'] = 0
data['drug_resist'].loc[data['Resistance Mutation'] == 'Yes'] = 1
# Out:
# /Users/sergigomezpalleja/anaconda3/envs/kaggle/lib/python3.6/site-packages/pandas/core/indexing.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
data.loc[data['drug_resist'] == 1].shape[0] / data.shape[0]
# Out:
# 0.0035575033663455403

# %%
df_site_1 = data.groupby(['Primary site']).agg({'drug_resist': 'sum'})
df_site_2 = data.groupby(['Primary site']).agg({'drug_resist': 'count'})
df_site_1['Percentage'] = 100*df_site_1['drug_resist'].values / df_site_2['drug_resist'].values
df_site_1.sort_values(by = 'Percentage', ascending = False).head(n = 10)
# Out:
#                                     drug_resist  Percentage
# Primary site
# soft_tissue                                 361    1.860345
# haematopoietic_and_lymphoid_tissue         1346    0.923233
# lung                                        582    0.764201
# prostate                                     32    0.323494
# breast                                       83    0.271962
# NS                                           25    0.237891
# skin                                         97    0.151340
# pancreas                                      1    0.005941
# central_nervous_system                        1    0.003473
# thyroid                                       1    0.002892

# %%
#df = data[data['Primary site'].isin(['soft_tissue','haematopoietic_and_lymphoid_tissue','lung'])]
df = data[data['Primary site'] == 'haematopoietic_and_lymphoid_tissue']

# %%
df.shape[0] / data.shape[0]
# Out:
# 0.20492118956390715

# %%
data2 = pd.read_csv('CosmicResistanceMutations.tsv',delimiter='\t')

# %%
data2.shape
# Out:
# (2442, 22)

# %%
data2.head()
# Out:
#   Sample Name  Sample ID Gene Name       Transcript Census Gene  Drug Name  \
# 0          29    1069291    PDGFRA  ENST00000257290         Yes   Imatinib
# 1      903854     903854      ABL1  ENST00000318560         Yes   Imatinib
# 2      904114     904114      ABL1  ENST00000318560         Yes   Imatinib
# 3      905456     905456      ABL1  ENST00000318560         Yes   Imatinib
# 4     1040049    1040049      EGFR  ENST00000275493         Yes  Gefitinib
#
#   ID Mutation AA Mutation CDS Mutation                      Primary Tissue  \
# 0   COSM12432     p.D842V          c.?                         soft_tissue
# 1   COSM12574     p.E255V     c.764A>T  haematopoietic_and_lymphoid_tissue
# 2   COSM12622     p.Y253F          c.?  haematopoietic_and_lymphoid_tissue
# 3   COSM12611     p.E355G    c.1064A>G  haematopoietic_and_lymphoid_tissue
# 4    COSM6240     p.T790M    c.2369C>T                                lung
#
#   ...                         Histology  \
# ...

# %%
df.head()
# Out:
#    Gene name Accession Number  Gene CDS length HGNC ID Sample name  ID_sample  \
# 0       JAK2  ENST00000381652             3399    6192      990000     990000
# 6       NRAS  ENST00000369535              570    7989      bar-11     717900
# 16       KIT  ENST00000288135             2931    6342      E12573     821900
# 23    CDKN2A  ENST00000304494              471    1787      925900     925900
# 26     CEBPA  ENST00000498907             1077    1833      987400     987400
#
#     ID_tumour                        Primary site Site subtype 1  \
# 0      905319  haematopoietic_and_lymphoid_tissue             NS
# 6      618867  haematopoietic_and_lymphoid_tissue             NS
# 16     741630  haematopoietic_and_lymphoid_tissue             NS
# 23     842667  haematopoietic_and_lymphoid_tissue             NS
# 26     902938  haematopoietic_and_lymphoid_tissue             NS
#
#    Site subtype 2     ...     FATHMM prediction FATHMM score  \
# ...
